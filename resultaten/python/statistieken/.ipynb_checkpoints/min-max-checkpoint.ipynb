# %%
import pandas as pd
merged=pd.read_csv("/Users/lennertbontinck/Documents/github/bachelorproef-compressie/resultaten/csv/merged.csv")

# %%
max_sharpness = merged.groupby(['image_id',], sort=False)['sharpness', 'extension'].max().to_frame()
max_sharpness = max_sharpness.rename(columns = {'sharpness':'max_sharpness'})

min_sharpness = merged.groupby(['image_id'], sort=False)['sharpness'].min().to_frame()
min_sharpness = min_sharpness.rename(columns = {'sharpness':'min_sharpness'})

max_color_contrast =  merged.groupby(['image_id'], sort=False)['color_contrast'].max().to_frame()
max_color_contrast = max_color_contrast.rename(columns = {'color_contrast':'max_color_contrast'})

min_color_contrast =  merged.groupby(['image_id'], sort=False)['color_contrast'].min().to_frame()
min_color_contrast = min_color_contrast.rename(columns = {'color_contrast':'min_color_contrast'})

max_general =  merged.groupby(['image_id'], sort=False)['general'].max().to_frame()
max_general = max_general.rename(columns = {'general':'max_general'})

min_general =  merged.groupby(['image_id'], sort=False)['general'].min().to_frame()
min_general = min_general.rename(columns = {'general':'min_general'})

# %%
merged_min_max=max_sharpness.merge(min_sharpness,on="image_id")
merged_min_max=merged_min_max.merge(max_color_contrast,on="image_id")
merged_min_max=merged_min_max.merge(min_color_contrast,on="image_id")
merged_min_max=merged_min_max.merge(max_general,on="image_id")
merged_min_max=merged_min_max.merge(min_general,on="image_id")
merged_min_max
# Out:
#           max_sharpness  min_sharpness  max_color_contrast  \
# image_id
# 1                     5              2                   5
# 2                     4              2                   5
# 3                     5              4                   5
# 4                     4              2                   5
# 5                     5              2                   5
# 6                     5              2                   5
# 7                     5              3                   5
# 8                     4              2                   4
# 9                     5              3                   5
# 10                    5              3                   5
# 11                    5              4                   5
# 12                    5              3                   5
# 13                    5              3                   5
# 14                    5              4                   5
# 15                    5              3                   5
# ...
